# %% [markdown]
# # Environment Setup
#
# Create new python env from requirements

# %%
# !python -m venv pyenv
# !pyenv\Scripts\activate
# !pip install -r requirements.txt

# %% [markdown]
# Activate environment and create jupyter kernel

# %%
# !.\pyenv\Scripts\Activate.ps1
# !python -m ipykernel install --user --name=pyenv
